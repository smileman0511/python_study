# %%
# 65 -> "A"
chr(65)

# "A" -> 65
ord("A")
# Out:
# 65

# %%
password = "test123"

for i in password:
    print(chr(ord(i) * 5000), end="")
# Out:
# 򍦠񻒨򌘘򍦠𻴈𽂐𾐘

# %%
expression = input("수식을 입력하세요.\nex)10+10\n")
# Out:
# 수식을 입력하세요.
# ex)10+10
#  sum([i for i in range(10)])

# %%
eval(expression)
# Out:
# 45

# %%
data1 = format(10000000, ",")
print(data1)

data2 = format(10000000, "_")
print(data2)

print(type(data1))
print(type(data2))
# Out:
# 10,000,000
# 10_000_000
# <class 'str'>
# <class 'str'>

# %%
int(data1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 int(data1)
#
# ValueError: invalid literal for int() with base 10: '10,000,000'

# %%
int(data2)
# Out:
# 10000000

# %%
divmod(10, 3)
# Out:
# (3, 1)

# %%
# 오사오입
# 값이 1~4까지일때 버림
# 값이 5일때 
# 앞 자리가 홀수면 반올림
# 앞 자리가 짝수면 버림

print(round(1.5))
print(round(2.5))
print(round(3.5))
print(round(4.5))
# Out:
# 2
# 2
# 4
# 4

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %% [markdown]
# ### 문자열 함수

# %%
# count
print("abcdeed".count("e"))
# Out:
# 2

# %%
# find
# 첫 번째 e의 인덱스 번호
print("abcdeedasdsadsadsde".find("e"))
# Out:
# 4

# %%
# 마지막 e의 인덱스 번호
print("abcdeedasdsadsadsde".rfind("e"))
# Out:
# 18

# %%
"a".upper()
# Out:
# 'A'

# %%
"A".lower()
# Out:
# 'a'

# %%
# 파스칼 표기법
"apple".capitalize()
# Out:
# 'Apple'

# %%
# 문자열, 리스트
print("a".join("b"))
print("apple".join("b"))
print("합쳐줘 제발!".join("b"))
# Out:
# b
# b
# b

# %%
li4 = [str((i + 1) * 10) for i in range(5)]

# %%
li4
# Out:
# ['10', '20', '30', '40', '50']

# %%
", ".join(li4)
# Out:
# '10, 20, 30, 40, 50'

# %%
str1 = "Life is to short"

# %%
# 2. 값이 바뀌면 새롭게 반환
# 새로운 문자열 리턴
str1.replace("short", "Long")
# Out:
# 'Life is to Long'

# %%
str1
# Out:
# 'Life is to short'

# %%
# 문자열 내부의 값이 정수로만 이루어져있는 확인 -> bool
"10".isdigit()
# Out:
# True

# %%
"10r".isdigit()
# Out:
# False

# %%
num1 = input("정수를 입력하세요.")
# Out:
# 정수를 입력하세요. 정수

# %%
if num1.isdigit():
    num1 = int(num1)
else:
    print("정신 차려!")
# Out:
# 정신 차려!

# %%
# 문자가 포함되었는지 확인하는 메서드
num1.isalpha()
# Out:
# True

# %%
data3 = "******da***************da*********"

# %%
print(data3.replace("*", ""))
# Out:
# dada

# %%
data3[data3.find("d"):]
# Out:
# 'da***************da*********'

# %%
data3.lstrip("*")
# Out:
# 'da***************da*********'

# %%
data3.rstrip("*")
# Out:
# '******da***************da'

# %%
data3.strip("*")
# Out:
# 'da***************da'

# %%
"2123.1.21.21.21.215561.1".split(".")
# Out:
# ['2123', '1', '21', '21', '21', '215561', '1']

# %%
names = "짱구", "하영", "수지"
score = 20, 40, 60
address = "떡잎마을", "강남", "압구정"

# %%
for i in zip(names, score, address):
    print(i)
# Out:
# ('짱구', 20, '떡잎마을')
# ('하영', 40, '강남')
# ('수지', 60, '압구정')
