# %%
# 65 -> "A"
chr(65)

# "A" -> 65
ord("A")
# Out:
# 65

# %%
password = "test123"

for i in password:
    print(chr(ord(i) * 100), end="")
# Out:
# ⵐ❴ⳬⵐጤᎈᏬ

# %%
expression = input("수식을 입력하세요.\nex)10+10\n")
# Out:
# 수식을 입력하세요.
# ex)10+10
#  sum([10, 20])

# %%
eval(expression)
# Out:
# 30

# %%
data1 = format(1000000, ",")
print(data1)

data2 = format(1000000, "_")
print(data2)

print(type(format(100000000, ",")))
print(type(format(100000000, "_")))
# Out:
# 1,000,000
# 1_000_000
# <class 'str'>
# <class 'str'>

# %%
divmod(10, 3)
# Out:
# (3, 1)

# %%
# 오사오입
# 값이 1 ~ 4까지일 때 내림

# 

print((round()1.5)

# %% [markdown]
# ## 문자열 함수

# %%
# count
print("abcdeed".count("e"))
# Out:
# 2

# %%
# find
# 첫 번째 e의 인덱스 번호
print("abcdeed".find("e"))
# Out:
# 4

# %%
# 마지막 e의 인덱스 번호
print("abcfasfrwecvaeweewe".rfind("e"))
# Out:
# 18

# %%
"a".upper()
# Out:
# 'A'

# %%
"a".lower()
# Out:
# 'a'

# %%
# 파스칼 표기법
"apple".capitalize()
# Out:
# 'Apple'

# %%
# 문자열, 리스트
"a".join("b")
# Out:
# 'b'

# %%
li4 = [str((i + 1) * 10) for i in range(5)]

# %%
li4
# Out:
# ['10', '20', '30', '40', '50']

# %%
", ".join(li4)
# Out:
# '10, 20, 30, 40, 50'

# %%
str1 = "Life is to short"

# %%
# 2. 값이 바뀌면 새롭게 반환
# 원본이 바뀌지 않고, 새로운 문자열을 리턴
str1.replace("short", "long")
# Out:
# 'Life is to long'

# %%
# 문자열 내부의 값이 정수로만 이루어져있는지 확인 -> bool
"10".isdigit()
# Out:
# True

# %%
"10r".isdigit()
# Out:
# False

# %%
num1 = input("정수를 입력하새요.")
# Out:
# 정수를 입력하새요. 정수

# %%
if num1.isdigit():
    num1 = int(num1)
else:
    print("정신 차려!")
# Out:
# 정신 차려!

# %%
# 문자가 포함되었는지 확인하는 메서드
num1.isalpha()
# Out:
# True

# %%
data3 = "








8888888"

# %%
names = "짱구", "하영", "수지" 
score = 20, 40, 60
address = "떡잎마을", "강남", "압구정"

# %%
for i in zip(names, score, address):
    print(i)
# Out:
# ('짱구', 20, '떡잎마을')
# ('하영', 40, '강남')
# ('수지', 60, '압구정')
