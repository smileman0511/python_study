# %%
# 저장공간에서 호출했을 때는 주소값이 들어가있다. name에는 주소가 들어가 있다. 주소를 호출하지만 값을 출력한다.
name = "홍길동"
name
# Out:
# '홍길동'

# %%
name = "장보고"
#원시타입의 주소가 바껴서 덮어쓰기 처럼 보인다.
print(name)
# Out:
# 장보고

# %%
age = 20

# %%
print(name + 20)
# 1. 장보고20 - JS처럼 자동형변환 불가!
# 2. None
# 3. 오류 - TypeError
# int + string은 타입에러
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(name + 20)
#       2 # 1. 장보고20 - JS처럼 자동형변환 불가!
#       3 # 2. None
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 숫자로 시작하면 안된다.
12name = "홍길동"

# %%
# 특수문자는 _만 사용할 수 있다.
!@name = '홍길동'

# %%
_name = "홍길동"

# %%
#카멜 표기법 사용 불가
nAme = "홍길동"

# %%
# 공백문자 사용할 수 없다.
na me = "나미"

# %%
# 한글 변수명을 사용할 수 없다.
이름 = "홍길동"

# %%
my_name = "홍길동"
