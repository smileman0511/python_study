# %%
name = input("이름을 입력하세요!")
# Out:
# 이름을 입력하세요! 홍길동

# %%
print(name)
# Out:
# 홍길동

# %%
# 두 수를 입력하고 그 결과를 더해서 출력
num1 = input("첫 번째 정수를 입력하세요.")
num2 = input("두 번재 정수를 입력하세요.")
# Out:
# 첫 번째 정수를 입력하세요. 20
# 두 번재 정수를 입력하세요. 50

# %%
# 연결 → 연산
result = int(num1) + int(num2)
print(f"{result}")
# Out:
# 70
