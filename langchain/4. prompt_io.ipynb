# %% [markdown]
# # 프롬프트 저장, 불러오기

# %% [markdown]
# ## JSON

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-qe-eR7H_eASs

# %%
base_path = r"D:\back_0900_kdh\python\resource"

# %%
base_path
# Out:
# 'D:\\back_0900_kdh\\python\\resource'

# %%
file_path = os.path.join(base_path, "prompt.json")

# %%
file_path
# Out:
# 'D:\\back_0900_kdh\\python\\resource\\prompt.json'

# %%
with open(file_path, "w") as f:
    f.write("""
        {
            "_type": "prompt",
            "template": "{country}에 대해서 어떻게 알고 있어요?",
            "input_variables": ["country"]
        }
    """)

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = load_prompt(file_path)

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "한국"
})

# %%
result.content
# Out:
# '한국은 동아시아에 위치한 나라로, 수도는 서울이며 인구는 약 5천만 명 정도입니다. 한국은 고도의 경제력을 가지고 있으며 세계적으로 유명한 기업들이 많이 있습니다. 또한 한국은 고유의 문화와 전통을 가지고 있으며 한류 열풍으로 전 세계적으로 인기를 끌고 있습니다. 한국의 음식은 매우 맛있고 특이하며 한국의 역사와 문화를 경험할 수 있는 다양한 관광지가 있습니다. 한국은 또한 고속 인터넷과 첨단 기술 분야에서 선두를 달리고 있습니다.'

# %% [markdown]
# ## YAML 파일

# %%
file_path = os.path.join(base_path, "prompt02.yaml")

# %%
file_path
# Out:
# 'D:\\back_0900_kdh\\python\\resource\\prompt02.yaml'

# %%
with open(file_path, "w") as f:
    f.write("""  
"_type": "prompt"
"template": "{country}에 대해서 어떻게 알고 있어요?"
"input_varoables": ["country"]
    """)

# %%
load_prompt(file_path)
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에 대해서 어떻게 알고 있어요?')

# %%
prompt = PromptTemplate.from_file(file_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 prompt = PromptTemplate.from_file(file_path)
#
# NameError: name 'PromptTemplate' is not defined

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "일본"
})

# %%
print(result.content)
# Out:
# {
#   "country": "일본"
# }
