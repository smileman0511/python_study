# %% [markdown]
# # 프롬프트 저장, 불러오기

# %% [markdown]
# ## JSON

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-VZytJ5BN3ErM

# %%
base_path = r"C:\back_0900_ksh\python\resource"

# %%
base_path
# Out:
# 'C:\\back_0900_ksh\\python\\resource'

# %%
file_path = os.path.join(base_path, "prompt.json")

# %%
file_path
# Out:
# 'C:\\back_0900_ksh\\python\\resource\\prompt.json'

# %%
with open(file_path, "w") as f:
    f.write("""
        {
            "_type": "prompt",
            "template": "{country}에 대해서 어떻게 알고 있어요?",
            "input_variables": ["country"]
        }
    """)

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = load_prompt(file_path)

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "한국"
})

# %%
result.content
# Out:
# '한국은 동아시아에 위치한 나라로, 수도는 서울이며 인구는 약 5천만 명 정도입니다. 한국은 역사적으로 고대부터 현대까지 다양한 문화와 전통을 갖고 있으며, 한류와 K-pop 등의 문화 콘텐츠로 세계적으로 유명해졌습니다. 또한 한국은 경제적으로도 세계적으로 경쟁력을 갖춘 나라로, 기술과 산업 분야에서 선두를 달리고 있습니다. 한국의 음식은 매운맛과 강한 양념이 특징이며, 김치, 불고기, 떡볶이 등이 대표적인 음식입니다. 한국의 전통 의상인 한복도 아름다운 문화유산으로 유명합니다. 한국은 또한 아름다운 자연 경치와 문화유산을 갖추고 있어 많은 관광객들이 방문하는 인기 있는 여행지입니다.'

# %% [markdown]
# ## YAML 파일

# %%
file_path = os.path.join(base_path, "prompt02.yaml")

# %%
file_path
# Out:
# 'C:\\back_0900_ksh\\python\\resource\\prompt02.yaml'

# %%
with open(file_path, "w") as f:
    f.write("""
"_type": "prompt"
"template": "{country}에서 가장 유명한 음식이 어떤건가요?"
"input_variables": ["country"]
    """)

# %%
load_prompt(file_path)
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에서 가장 유명한 음식이 어떤건가요?')

# %%
prompt = load_prompt(file_path)

# %%
prompt.format(country="일본")
# Out:
# '일본에서 가장 유명한 음식이 어떤건가요?'

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "일본"
})

# %%
print(result.content)
# Out:
# 일본에서 가장 유명한 음식 중 일부는 다음과 같습니다:
#
# 1. 초밥 (Sushi): 신선한 회와 식초로 맛을 낸 밥을 함께 먹는 일본 전통 음식입니다.
# 2. 라면 (Ramen): 면과 육수, 고기, 채소 등을 함께 끓여 만든 일본의 대표적인 면 요리입니다.
# 3. 우동 (Udon): 굵은 면과 다양한 재료를 넣어 만든 일본의 전통 면 요리입니다.
# 4. 텐동 (Tendon): 새우, 채소 등을 튀겨낸 후 밥 위에 올려 먹는 일본의 전통 음식입니다.
# 5. 사케 (Sake): 일본의 전통 술로, 쌀을 발효시켜 만든 술입니다.
#
# 이 외에도 일본에는 다양한 지방 특산물과 전통 음식이 있어서 많은 사람들이 그 맛을 즐기고 있습니다.

# %%
result = chat.invoke("학생들이 먹기 좋은 점심 메뉴 10가지만 리스트로 추천해줘!")

# %%
print(result.content)
# Out:
# 1. 돈까스
# 2. 불고기 비빔밥
# 3. 치킨 샐러드
# 4. 김치찌개
# 5. 새우튀김우동
# 6. 떡볶이
# 7. 삼겹살 김치찜
# 8. 해물파전
# 9. 된장찌개
# 10. 갈비탕

# %%
result = chat.invoke("한국 남자들이 좋아서 환장하는 소울푸드 10가지만 리스트로 추천해줘!")

# %%
print(result.content)
# Out:
# 1. 김치찌개
# 2. 불고기
# 3. 된장찌개
# 4. 갈비탕
# 5. 떡볶이
# 6. 삼겹살
# 7. 냉면
# 8. 순두부찌개
# 9. 된장국
# 10. 비빔밥
