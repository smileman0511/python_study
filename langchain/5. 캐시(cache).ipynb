# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

# v1.2.6
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
# Out:
# sk-proj-qe-eR7H_eASs

# %%
# 모든 llm의 response가 메모리에 저장됨
in_memory_cache = InMemoryCache()
set_llm_cache(in_memory_cache)

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
import time
from datetime import timedelta

# %%
def check_laptime(message):

    start_time = time.time()
    response = chat.invoke(message)
    end_time = time.time()

    elapsed_time = end_time - start_time
    print(f"경과 시간: {str(timedelta(seconds=elapsed_time))}")
    print(f"글자 수: {len(response.content)}")
    print(response.content)

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘!")
# Out:
# 경과 시간: 0:00:04.489933
# 글자 수: 362
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)
#
# 2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.
#
# 3. 반죽을 밀가루를 뿌린 작업대에 올려서 도우 형태로 눌러준다.
#
# 4. 토마토 소스를 도우 위에 발라준 후 치즈와 토핑 재료를 올려준다.
#
# 5. 오븐을 200도로 예열한 후 피자를 넣어 15-20분간 굽는다.
#
# 6. 굽기가 끝나면 피자를 꺼내서 잘라서 먹는다.
#
# 이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다.맛있게 즐기세요!

# %%
check_laptime("치킨은 어떻게 만들어야 돼?")
# Out:
# 경과 시간: 0:00:03.041125
# 글자 수: 304
# 치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.
#
# 마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김기를 사용하여 튀겨도 좋습니다.
#
# 치킨을 먹기 좋은 크기로 잘라내어 소스를 발라주거나 곁들여 먹으면 완성됩니다. 고소한 치킨을 만들기 위해서는 마리네이드를 충분히 재워주고, 고기가 익을 때까지 꼼꼼히 조리해야 합니다.

# %%
print(in_memory_cache._cache)
# Out:
# {('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루를 뿌린 작업대에 올려서 도우 형태로 눌러준다.\n\n4. 토마토 소스를 도우 위에 발라준 후 치즈와 토핑 재료를 올려준다.\n\n5. 오븐을 200도로 예열한 후 피자를 넣어 15-20분간 굽는다.\n\n6. 굽기가 끝나면 피자를 꺼내서 잘라서 먹는다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다.맛있게 즐기세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루를 뿌린 작업대에 올려서 도우 형태로 눌러준다.\n\n4. 토마토 소스를 도우 위에 발라준 후 치즈와 토핑 재료를 올려준다.\n\n5. 오븐을 200도로 예열한 후 피자를 넣어 15-20분간 굽는다.\n\n6. 굽기가 끝나면 피자를 꺼내서 잘라서 먹는다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다.맛있게 즐기세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 28, 'total_tokens': 408, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjRWAVvHdkFTjyZSQt9wPdSh15q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-bfbb-7571-9d5e-b62430cea761-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 380, 'total_tokens': 408, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))], ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\uce58\\ud0a8\\uc740 \\uc5b4\\ub5bb\\uac8c \\ub9cc\\ub4e4\\uc5b4\\uc57c \\ub3fc?", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김기를 사용하여 튀겨도 좋습니다.\n\n치킨을 먹기 좋은 크기로 잘라내어 소스를 발라주거나 곁들여 먹으면 완성됩니다. 고소한 치킨을 만들기 위해서는 마리네이드를 충분히 재워주고, 고기가 익을 때까지 꼼꼼히 조리해야 합니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김기를 사용하여 튀겨도 좋습니다.\n\n치킨을 먹기 좋은 크기로 잘라내어 소스를 발라주거나 곁들여 먹으면 완성됩니다. 고소한 치킨을 만들기 위해서는 마리네이드를 충분히 재워주고, 고기가 익을 때까지 꼼꼼히 조리해야 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 293, 'prompt_tokens': 24, 'total_tokens': 317, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5- ...

# %%
for i in in_memory_cache._cache.keys():
    print(i)
# Out:
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\uce58\\ud0a8\\uc740 \\uc5b4\\ub5bb\\uac8c \\ub9cc\\ub4e4\\uc5b4\\uc57c \\ub3fc?", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true, "temperature": 0.1}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')

# %%
for i in in_memory_cache._cache.values():
    print(i)
# Out:
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루를 뿌린 작업대에 올려서 도우 형태로 눌러준다.\n\n4. 토마토 소스를 도우 위에 발라준 후 치즈와 토핑 재료를 올려준다.\n\n5. 오븐을 200도로 예열한 후 피자를 넣어 15-20분간 굽는다.\n\n6. 굽기가 끝나면 피자를 꺼내서 잘라서 먹는다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다.맛있게 즐기세요!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 준비물: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일, 토마토 소스, 치즈, 토핑 재료(페퍼로니, 양파, 피망 등)\n\n2. 반죽 만들기: 밀가루, 물, 소금, 설탕, 이스트, 올리브 오일을 섞어 부드러운 반죽을 만든다. 이후 1시간 정도 발효시켜준다.\n\n3. 반죽을 밀가루를 뿌린 작업대에 올려서 도우 형태로 눌러준다.\n\n4. 토마토 소스를 도우 위에 발라준 후 치즈와 토핑 재료를 올려준다.\n\n5. 오븐을 200도로 예열한 후 피자를 넣어 15-20분간 굽는다.\n\n6. 굽기가 끝나면 피자를 꺼내서 잘라서 먹는다.\n\n이렇게 하면 집에서 간단하게 맛있는 피자를 만들 수 있습니다.맛있게 즐기세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 380, 'prompt_tokens': 28, 'total_tokens': 408, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjRWAVvHdkFTjyZSQt9wPdSh15q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-bfbb-7571-9d5e-b62430cea761-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 380, 'total_tokens': 408, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]
# [ChatGeneration(text='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김기를 사용하여 튀겨도 좋습니다.\n\n치킨을 먹기 좋은 크기로 잘라내어 소스를 발라주거나 곁들여 먹으면 완성됩니다. 고소한 치킨을 만들기 위해서는 마리네이드를 충분히 재워주고, 고기가 익을 때까지 꼼꼼히 조리해야 합니다.', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='치킨을 만들기 위해서는 먼저 신선한 닭고기를 준비해야 합니다. 닭고기를 손질하고 씻은 후, 마리네이드에 재워 맛을 내줍니다. 일반적으로는 간장, 설탕, 다진 마늘, 후추, 생강 등을 사용하여 마리네이드를 만들어 사용합니다.\n\n마리네이드를 한 닭고기를 후라이팬에 넣고 고기가 익을 때까지 굽거나 오븐에 구워주면 됩니다. 또는 튀김기를 사용하여 튀겨도 좋습니다.\n\n치킨을 먹기 좋은 크기로 잘라내어 소스를 발라주거나 곁들여 먹으면 완성됩니다. 고소한 치킨을 만들기 위해서는 마리네이드를 충분히 재워주고, 고기가 익을 때까지 꼼꼼히 조리해야 합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 293, 'prompt_tokens': 24, 'total_tokens': 317, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIjV7NolqcPB1AC6iWMSiZjj085l', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ea-d15c-79b2-8a65-da46d2c5dba9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 24, 'output_tokens': 293, 'total_tokens': 317, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]

# %%
# 프로그램 종료 시 삭제 자동 삭제
# 캐시 삭제
in_memory_cache.clear()

# %%
in_memory_cache._cache
# Out:
# {}

# %% [markdown]
# ## 디버그 설정

# %%
from langchain_core.globals import set_debug

# %%
set_debug(True)

# %%
chat.invoke("랍스터는 누구의 후손이니?")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: 랍스터는 누구의 후손이니?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "랍스터는 게의 후손입니다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "랍스터는 게의 후손입니다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 12,
#                 "prompt_tokens": 23,
#                 "total_tokens": 35,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "id": "chatcmpl-DfIoeiFGqMtFqYHTeJP10AIl26Dhc",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019e24ef-afdf-73d2-a234-4f73cc6c7883-0",
#             "usage_metadata": {
#               "input_tokens": 23,
#               "output_tokens": 12,
#               "total_tokens": 35,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 12,
#       "prompt_tokens": 23,
#       "total_tokens": 35,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null,
#     "id": "chatcmpl-DfIoeiFGqMtFqYHTeJP10AIl26Dhc",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# AIMessage(content='랍스터는 게의 후손입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 23, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIoeiFGqMtFqYHTeJP10AIl26Dhc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ef-afdf-73d2-a234-4f73cc6c7883-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 12, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
set_debug(False)

# %%
set_llm_cache(None)
