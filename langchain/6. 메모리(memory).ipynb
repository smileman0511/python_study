# %%
from dotenv import load_dotenv
import os
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-qe-eR7H_eASs

# %%
chat = ChatOpenAI(temperature=0)

# %%
chat.invoke("게는 누구의 후손이니?")
# Out:
# AIMessage(content='게는 고대 신화에서 태양신 하이페리온(Hyperion)과 지구신 테아(Tea)의 후손으로 묘사되었습니다. 이들은 티탄(Titan) 신들의 일원으로, 그들의 후손 중 하나가 바로 게입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 20, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIsYcrTWYwtDXdiXB60abksLaVym', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24f3-6080-7bd1-a75a-103098903eac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 83, 'total_tokens': 103, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# # ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: Hi\nAI: How are you'}

# %%
print(type(memory))
# Out:
# <class 'langchain_classic.memory.buffer.ConversationBufferMemory'>

# %% [markdown]
# # return_message=True
# - history 객체에 AIMessage, HumanMessage로 저장하게 만든다.

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("내 이름은 춘식이야")
# Out:
# AIMessage(content='반가워, 춘식이! 무엇을 도와드릴까?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 25, 'prompt_tokens': 15, 'total_tokens': 40, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJU96UeYtWXVOoSQCJXOkOeJsQGY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2516-ed3d-7e80-a3db-d09b4bc308fd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 25, 'total_tokens': 40, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# # 체인

# %%
from langchain_classic.chains import ConversationChain

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_messages=True)

chain = ConversationChain(llm=llm, memory=memory)
# Out:
# C:\Users\5418c\AppData\Local\Temp\ipykernel_26064\3503874491.py:4: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use `langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   chain = ConversationChain(llm=llm, memory=memory)

# %%
result = chain.invoke("내 이름은 춘식이야!")

# %%
result
# Out:
# {'input': '내 이름은 춘식이야!',
#  'history': [HumanMessage(content='내 이름은 춘식이야!', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'response': '안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?'}

# %%
result = chain.invoke("내 이름은 춘식이야!")

# %%
result:["response"]

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='내 이름은 춘식이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='내 이름은 춘식이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
def print_memory():
    print(memory.load_memory_variables({}))

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='내 이름은 춘식이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='내 이름은 춘식이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 춘식님! 반가워요. 저는 OpenAI의 인공지능 언어 모델입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# # ConversationBufferWindowMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

# %%
memory.save_context({"input": "1"}, {"output": "1"})
memory.save_context({"input": "2"}, {"output": "2"})
memory.save_context({"input": "3"}, {"output": "3"})
memory.save_context({"input": "4"}, {"output": "4"})
memory.save_context({"input": "5"}, {"output": "5"})
memory.save_context({"input": "6"}, {"output": "6"})

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='3', additional_kwargs={}, response_metadata={}), AIMessage(content='3', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='4', additional_kwargs={}, response_metadata={}), AIMessage(content='4', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='5', additional_kwargs={}, response_metadata={}), AIMessage(content='5', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='6', additional_kwargs={}, response_metadata={}), AIMessage(content='6', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("내 이름은 춘식이야!")
chain.invoke("피자 어떻게 만들어?")
chain.invoke("개의 조상이 뭐야?")
chain.invoke("김세종은 일본에 갈 수 있어?")
chain.invoke("문윤성의 반댓말은?")
chain.invoke("예스규호는 어떤 일을 할 것 같아?")

chain.invoke("내 이름이 뭐야?")
# Out:
# {'input': '내 이름이 뭐야?',
#  'history': [HumanMessage(content='개의 조상이 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='개의 조상은 늑대입니다. 개는 수천 년 전에 늑대로부터 진화했습니다. 늑대는 개와 매우 밀접한 가족 관계를 가지고 있으며, 개의 특성 중 일부는 늑대로부터 유래되었습니다. 늑대는 사회적 동물이며 무리를 이루어 사는 습성을 가지고 있습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='김세종은 일본에 갈 수 있어?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='죄송합니다, 김세종이 일본에 갈 수 있는지에 대한 정보는 제가 알 수 없습니다. 김세종이 일본 여행을 계획 중이라면 해당 국가의 입국 요건을 확인해보시는 것이 좋을 것 같습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='문윤성의 반댓말은?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='죄송합니다, 문윤성의 반댓말에 대한 정보는 제가 알 수 없습니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='예스규호는 어떤 일을 할 것 같아?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='예스규호가 어떤 일을 할 것인지에 대해서는 제가 알 수 없습니다. 예스규호의 성향이나 관심사에 따라 다양한 일을 할 수 있을 것입니다. 예스규호에게 직접 물어보시는 것이 가장 정확한 정보를 얻을 수 있는 방법일 것입니다.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'response': '죄송합니다, 당신의 이름에 대한 정보는 제가 알 수 없습니다.'}

# %% [markdown]
# # ConversationSummaryMemory

# %%
from langchain_classic.memory import ConversationSummaryMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryMemory(return_messages=True, llm=llm)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain
# Out:
# ConversationChain(memory=ConversationSummaryMemory(llm=ChatOpenAI(output_version=None, profile={'max_input_tokens': 16385, 'max_output_tokens': 4096, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000259FD484C50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000259FD485690>, root_client=<openai.OpenAI object at 0x00000259FD484610>, root_async_client=<openai.AsyncOpenAI object at 0x00000259FD484F90>, temperature=0.1, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True), chat_memory=InMemoryChatMessageHistory(messages=[]), return_messages=True), verbose=False, llm=ChatOpenAI(output_version=None, profile={'max_input_tokens': 16385, 'max_output_tokens': 4096, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x00000259FD484C50>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000259FD485690>, root_client=<openai.OpenAI object at 0x00000259FD484610>, root_async_client=<openai.AsyncOpenAI object at 0x00000259FD484F90>, temperature=0.1, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True), output_parser=StrOutputParser(), llm_kwargs={})

# %%
chain.invoke("우리반의 유중이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!")
# Out:
# {'input': '우리반의 유중이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!',
#  'history': [SystemMessage(content='', additional_kwargs={}, response_metadata={})],
#  'response': '그렇군요! 유중이는 정말 멋진 사람이군요. 그가 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런하다니 정말 대단한 사람이겠네요. 그런 사람이라면 주변 사람들에게 영감을 줄 수 있을 것 같아요.'}

# %%
chain.invoke("그리고 우리반의 윤성이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야!")
# Out:
# {'input': '그리고 우리반의 윤성이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야!',
#  'history': [SystemMessage(content='The human praises their classmate Yoojung, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojung as an impressive individual who can inspire those around him.', additional_kwargs={}, response_metadata={})],
#  'response': '윤성이는 정말 친절하고 다정한 사람인가 봐요! 사랑을 나눠주는 모습이 정말 멋지네요. 함께 있으면 기분이 좋아지는 친구인가 봐요.'}

# %%
print_memory()
# Out:
# {'history': [SystemMessage(content="The human praises their classmate Yoojung, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojung as an impressive individual who can inspire those around him. The human then mentions their classmate Yoonseong, who is known for spreading love and kindness everywhere. The AI agrees, noting Yoonseong's kindness and loving nature, and how being around him can uplift one's spirits.", additional_kwargs={}, response_metadata={})]}

# %%
chain.invoke("유중이는 어떤 사람이야?")
# Out:
# {'input': '유중이는 어떤 사람이야?',
#  'history': [SystemMessage(content="The human praises their classmate Yoojung, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojung as an impressive individual who can inspire those around him. The human then mentions their classmate Yoonseong, who is known for spreading love and kindness everywhere. The AI agrees, noting Yoonseong's kindness and loving nature, and how being around him can uplift one's spirits.", additional_kwargs={}, response_metadata={})],
#  'response': '유중이는 잘생기고 건장하며 부유하며 끈기가 강한 사람으로 묘사됩니다. 주변 사람들에게 영감을 줄 수 있는 인상적인 인물이에요.'}

# %% [markdown]
# # ConversationSummaryBufferMemory
# - 요약본의 토큰 수를 제한하는 메모리

# %%
from langchain_classic.memory import ConversationSummaryBufferMemory

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationSummaryBufferMemory(
    llm=llm,
    return_message=True,
    max_token_limit=50
)
# Out:
# C:\Users\5418c\AppData\Local\Temp\ipykernel_26064\826747280.py:2: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("뀨트북은 이제 보내줄 때가 된 것 같아!")
chain.invoke("예스규호는 요즘 얼굴이 잘생긴 유중라인이야")
chain.invoke("약소훈도 요즘 핸섬한 유중라인으로 올라탔어!")

chain.invoke("유중라인은 누구누구야?")
# Out:
# {'input': '유중라인은 누구누구야?',
#  'history': "System: The human mentions that it's time to send a laptop. The AI agrees that sending a laptop is a good idea and asks for more information on the type of laptop needed. The human then comments on Yes Gyuho being a good-looking 유중라인. The AI acknowledges this and asks for specific requirements for the laptop that needs to be sent. 약소훈도 요즘 핸섬한 유중라인으로 올라탔어! The AI agrees that 약소훈도 is popular as a handsome 유중라인 and inquires about the specific requirements for the laptop to be sent.",
#  'response': '유중라인은 한국어로 "유명한 중년 라인"을 의미합니다. 약소훈도는 한국의 유명한 중년 라인 중 한 명으로 알려져 있습니다. 그가 최근에 더욱 인기를 얻고 있는 것 같네요. 그럼 노트북을 보내기 위한 구체적인 요구 사항이 있을까요?'}

# %%
print_memory()
# Out:
# {'history': 'System: The human asks who 유중라인 is. The AI explains that 유중라인 means "famous middle-aged line" in Korean. 약소훈도 is known as one of the famous middle-aged lines in Korea and seems to be gaining more popularity recently. The AI then asks if there are specific requirements for the laptop to be sent.'}

# %% [markdown]
# # ConversationKGMemory

# %%
from langchain_community.memory.kg import ConversationKGMemory

# %%
memory = ConversationKGMemory(llm=llm, return_message=True)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("세종이는 피부가 뽀얗게 변해서 왔어! 올림피아 사우나가 그런 피부에 도움을 줬어!")
chain.invoke("올림피아 사우나는 계란과 식혜를 팔아! 민균이는 계란을 먹었고, 철민이는 식혜를 먹었어!")
chain.invoke("세종이가 간 사우나에서 음식을 먹은 사람은?")
# Out:
# {'input': '세종이가 간 사우나에서 음식을 먹은 사람은?',
#  'history': 'On 세종이: 세종이 피부가 뽀얗게 변해서 왔어 올림피아 사우나가. 세종이 간 사우나의 이름. 세종이 피부가 뽀얗게 변해서 왔다 올림피아 사우나.',
#  'response': '세종이가 간 사우나에서 음식을 먹은 사람은 세종이 본인입니다.'}

# %%
chain.invoke("내 취미는 축구, 야구, 농구야!")
chain.invoke("내가 좋아하는 음식은 돈까스, 치킨, 스테이크야!")
chain.invoke("내가 좋아하는 취미는?")
# Out:
# {'input': '내가 좋아하는 취미는?',
#  'history': '',
#  'response': '죄송합니다, 그 정보는 제가 알 수 없습니다. 하지만 다른 질문이 있으시면 도와드릴 수 있습니다.'}

# %% [markdown]
# # LCEL 방법 권장

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        휴먼을 도와주는 AI 도구입니다. 친절하게 답변하세요.
    """),
    # 저장소 메모리 위치
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}")
])

# %%
chain = prompt | chat

# %% [markdown]
# # 저장소(메모리) 생성

# %%
# redis, db
store = {}

def get_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "내 이름은 춘식이야!",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(result.content)
# Out:
# 안녕, 춘식이! 만나서 반가워. 무엇을 도와드릴까?

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 춘식이야!
# AI: 안녕, 춘식이! 만나서 반가워. 무엇을 도와드릴까?

# %%
result = chain_with_memory.invoke(
    {
        "question": "나는 오늘 저녁에 김치찌개를 먹을거야!",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "나는 오늘 저녁에 무엇을 먹을 것 같아?",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 춘식이야!
# AI: 안녕, 춘식이! 만나서 반가워. 무엇을 도와드릴까?
# Human: 나는 오늘 저녁에 김치찌개를 먹을거야!
# AI: 김치찌개는 정말 맛있는 선택이야! 집에서 직접 만들어 먹을 거니까 재료를 잘 준비하고 맛있게 요리해보는 건 어떨까? 혹시 레시피가 필요하면 알려줄까?
# Human: 나는 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택은 개인 취향에 따라 다르지만, 오늘 저녁에는 어떤 음식이 땡기는지 생각해보는 것도 좋을 것 같아. 중식, 일식, 양식 등 다양한 음식 중에서 선택해보는 것도 좋을 거야. 혹시 특별히 먹고 싶은 음식이 있나요?

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
).with_config(
    configurable={"session_id": "user2"}
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "나는 오늘 저녁에 무엇을 먹을 것 같아?",
    }
)

# %%
print(store["user2"])
# Out:
# Human: 나는 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택은 개인 취향에 따라 다를 수 있지만, 몇 가지 제안을 드릴게요. 한식을 좋아하신다면 비빔밥이나 불고기, 중식을 좋아하신다면 짜장면이나 탕수육, 양식을 좋아하신다면 파스타나 스테이크를 먹어보시는 것은 어떨까요? 또는 샐러드나 샌드위치도 좋은 선택이 될 수 있어요. 오늘의 기분에 맞게 맛있는 음식을 즐기시길 바랍니다.
