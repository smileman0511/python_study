# %%
from dotenv import load_dotenv
import os
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.prompts.chat import ChatPromptTemplate

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-VZytJ5BN3ErM

# %%
chat = ChatOpenAI(temperature=0)

# %%
chat.invoke("이음이라는 서비스는 어떤거야? 공식 사이트 주소 줘")
# Out:
# AIMessage(content='이음은 한국의 음악 스트리밍 서비스입니다. 이음의 공식 사이트 주소는 https://www.ihum.co.kr/ 입니다. 이음을 통해 다양한 음악을 감상하고 다운로드할 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 34, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUWC184CN3ufV0iQG20fOPGgrri', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-4a40-7673-8f2a-e923b7a6c620-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 34, 'output_tokens': 75, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("페일로그는 어떤 서비스야? 공식 사이트 주소 줘")
# Out:
# AIMessage(content='페일로그는 한국의 온라인 독서 및 독후감 공유 플랫폼입니다. 사용자들은 책을 읽고 감상평을 작성하고 다른 사람들과 소통할 수 있는 서비스를 제공합니다.\n\n공식 사이트 주소는 https://www.faillog.com/ 입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 101, 'prompt_tokens': 33, 'total_tokens': 134, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUYWi576N6nGtkLo45qx4kolbhL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-5358-7be2-81a8-3f751e9e4692-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 101, 'total_tokens': 134, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## ConversationBufferMemory

# %%
from langchain_classic.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23084\995385594.py:1: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you?"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': 'Human: Hi\nAI: How are you?'}

# %%
print(type(memory))
# Out:
# <class 'langchain_classic.memory.buffer.ConversationBufferMemory'>

# %% [markdown]
# ## return_message=True
# - history 객체에 AIMessage, HumanMessage로 저장하게 만든다.

# %%
memory = ConversationBufferMemory(return_messages=True)

# %%
memory.save_context(
    {"input": "Hi"},
    {"output": "How are you?"}
)

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}), AIMessage(content='How are you?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## 문제점

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
chat.invoke("내 이름은 세환이야!")
# Out:
# AIMessage(content='안녕하세요, 세환이! 만나서 반가워요. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 16, 'total_tokens': 51, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUdG4fNvxVKxbrcBtPHBrd90RW3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-6930-7ea1-b3c2-9496b68ba141-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 35, 'total_tokens': 51, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chat.invoke("내 이름이 뭐야?")
# Out:
# AIMessage(content='죄송합니다, 제가 이름을 가지고 있지는 않습니다. 저는 인공지능 어시스턴트입니다. 어떤 도움이 필요하신가요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 14, 'total_tokens': 66, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfJUrKJl8Nkcl2y81ZyZhIfALnk4j', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e2517-9da2-7740-9229-d17c147cde01-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 52, 'total_tokens': 66, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 체인

# %%
from langchain_classic.chains import ConversationChain

# %%
llm = ChatOpenAI(temperature=0.1)
memory = ConversationBufferMemory(return_messages=True)

chain = ConversationChain(llm=llm, memory=memory)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23084\3503874491.py:4: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use `langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   chain = ConversationChain(llm=llm, memory=memory)

# %%
result = chain.invoke("내 이름은 세환이야!")

# %%
result["response"]
# Out:
# '안녕하세요, 세환이! 반가워요. 저는 인공지능 비서입니다. 어떻게 도와드릴까요?'

# %%
result = chain.invoke("내 이름이 뭐라고?")

# %%
result["response"]
# Out:
# '안녕하세요, 세환이! 반가워요. 당신의 이름은 세환이에요. 어떻게 도와드릴까요?'

# %%
print(memory.load_memory_variables({}))
# Out:
# {'history': [HumanMessage(content='내 이름은 세환이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 세환이! 반가워요. 저는 인공지능 비서입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 세환이! 반가워요. 당신의 이름은 세환이에요. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
def print_memory():
    print(memory.load_memory_variables({}))

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='내 이름은 세환이야!', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 세환이! 반가워요. 저는 인공지능 비서입니다. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}), AIMessage(content='안녕하세요, 세환이! 반가워요. 당신의 이름은 세환이에요. 어떻게 도와드릴까요?', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %% [markdown]
# ## ConversationBufferWindowMemory

# %%
from langchain_classic.memory import ConversationBufferWindowMemory

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

# %%
memory.save_context({"input": "1"}, {"output": "1"})
memory.save_context({"input": "2"}, {"output": "2"})
memory.save_context({"input": "3"}, {"output": "3"})
memory.save_context({"input": "4"}, {"output": "4"})
memory.save_context({"input": "5"}, {"output": "5"})
memory.save_context({"input": "6"}, {"output": "6"})

# %%
print_memory()
# Out:
# {'history': [HumanMessage(content='3', additional_kwargs={}, response_metadata={}), AIMessage(content='3', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='4', additional_kwargs={}, response_metadata={}), AIMessage(content='4', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='5', additional_kwargs={}, response_metadata={}), AIMessage(content='5', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='6', additional_kwargs={}, response_metadata={}), AIMessage(content='6', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])]}

# %%
memory = ConversationBufferWindowMemory(return_messages=True, k=4)

chain = ConversationChain(llm=llm, memory=memory)

# %%
chain.invoke("내 이름은 세환이야!")
chain.invoke("피자 어떻게 만들어?")
chain.invoke("개의 조상이 뭐야?")
chain.invoke("김세종은 일본에 갈 수 있어?")
chain.invoke("문윤성의 반댓말은?")
chain.invoke("예스규호는 어떤 일을 할 것 같아?")


chain.invoke("내 이름이 뭐라고?")
# Out:
# {'input': '내 이름이 뭐라고?',
#  'history': [HumanMessage(content='개의 조상이 뭐야?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='그 질문에 대한 정확한 답변을 제공할 수 없어요. 개의 조상에 대해 더 알고 싶다면 전문가나 검색 엔진을 통해 정보를 찾아보시는 것을 추천해요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='김세종은 일본에 갈 수 있어?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='김세종은 일본에 갈 수 있어요. 일본은 한국인에게 비자 면제 혜택을 주고 있어서 한국 국적을 가진 김세종이 일본을 방문할 때 비자를 따로 신청하지 않아도 될 수 있어요. 다만, 현재는 코로나19로 인해 여행 제한이 있을 수 있으니 여행 계획을 세우실 때는 관련 정보를 미리 확인하시는 것이 좋아요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='문윤성의 반댓말은?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='그 질문에 대한 정확한 답변을 제공할 수 없어요. 문윤성의 반댓말에 대해 더 알고 싶다면 전문가나 검색 엔진을 통해 정보를 찾아보시는 것을 추천해요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]),
#   HumanMessage(content='예스규호는 어떤 일을 할 것 같아?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='예스규호가 어떤 일을 할지 정확히 알 수는 없지만, 예스규호가 무엇을 하고 싶어하는지에 따라 다를 수 있어요. 예스규호가 자신의 관심사나 역량을 바탕으로 선택할 수 있는 다양한 직업이 있을 거예요. 무엇을 하고 싶은지 고민해보고 그에 맞는 직업을 찾아보는 것이 좋을 것 같아요.', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[])],
#  'response': '그 질문에 대한 정확한 답변을 제공할 수 없어요. 당신의 이름에 대해 더 알고 싶다면 다시 말해주세요.'}

# %% [markdown]
# ## ConversationSummaryMemory

# %%
from langchain_classic.memory import ConversationSummaryMemory
from langchain_classic.chains import ConversationChain

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryMemory(llm=llm)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23084\2812279859.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryMemory(llm=llm)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("우리반의 유중이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!")
# Out:
# {'input': '우리반의 유중이는 핸섬하고 몸도 좋고, 돈도 많고, 엄청나게 부지런한 사람이야!',
#  'history': '',
#  'response': '그렇군요! 유중이는 정말 멋진 사람이군요. 그의 부지런함과 재능이 돈을 많이 벌게 해주고, 그것이 그의 외모와 건강에도 도움을 줄 것입니다. 부럽네요!'}

# %%
chain.invoke("그리고 우리반의 윤성이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야!")
# Out:
# {'input': '그리고 우리반의 윤성이는 쟁반으로 사랑을 여기저기 나눠주는 사람이야!',
#  'history': "The human praises their classmate Yoojoong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojoong's impressive qualities and speculating that his diligence and talent will help him earn a lot of money, which will in turn benefit his appearance and health. The AI expresses envy towards Yoojoong.",
#  'response': '네, 윤성이는 정말 친절하고 사랑스러운 사람인 것 같아요! 사랑을 나눠주는 모습은 주변 사람들에게 큰 영감을 줄 것 같아요. 그의 성품이 주변 사람들에게 긍정적인 영향을 미칠 거라고 생각해요.'}

# %%
print_memory()
# Out:
# {'history': "The human praises their classmate Yoojoong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojoong's impressive qualities and speculating that his diligence and talent will help him earn a lot of money, which will in turn benefit his appearance and health. The AI expresses envy towards Yoojoong. The human then mentions their classmate Yoonseong, who is known for spreading love and kindness. The AI agrees, noting that Yoonseong's actions will inspire those around him and have a positive impact on others."}

# %%
chain.invoke("유중이는 어떤 사람이야?")
# Out:
# {'input': '유중이는 어떤 사람이야?',
#  'history': "The human praises their classmate Yoojoong, describing him as handsome, fit, wealthy, and incredibly hardworking. The AI agrees, acknowledging Yoojoong's impressive qualities and speculating that his diligence and talent will help him earn a lot of money, which will in turn benefit his appearance and health. The AI expresses envy towards Yoojoong. The human then mentions their classmate Yoonseong, who is known for spreading love and kindness. The AI agrees, noting that Yoonseong's actions will inspire those around him and have a positive impact on others.",
#  'response': '유중이는 잘생기고, 몸매가 좋고, 부유하며 열심히 일하는 사람이야. 그의 노력과 재능이 그를 많은 돈을 벌게 할 거라고 생각해. 그 돈이 그의 외모와 건강에 도움이 될 거야. 나도 유중이를 부러워해.'}

# %% [markdown]
# ## ConversationSummaryBufferMemory
# - 요약본의 토큰 수를 제한하는 메모리

# %%
from langchain_classic.memory import ConversationSummaryBufferMemory

# %%
llm = ChatOpenAI(temperature=0.1)

memory = ConversationSummaryBufferMemory(
    llm=llm,
    return_messages=True,
    max_token_limit=50
)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_23084\2755807395.py:3: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationSummaryBufferMemory(

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("뀨트북은 이제 보내줄 때가 된 것 같아!")
chain.invoke("예스규호는 요즘 얼굴이 잘생긴 유중라인이야")
chain.invoke("약소훈도 요즘 핸섬한 유중라인으로 올라탔어!")

chain.invoke("유중라인은 누구누구니?")
# Out:
# {'input': '유중라인은 누구누구니?',
#  'history': [SystemMessage(content='The human mentions that it might be time to send a laptop. The AI agrees that sending a laptop could be a good decision and asks for more details on the brand or model to provide further information. The conversation then shifts to discussing the popular Chinese actor, Yeskyuho, and his good looks that have captured the hearts of many fans. 약소훈도 요즘 핸섬한 유중라인으로 올라탔어! The AI agrees that Yeskyuho is indeed handsome and charming, with his impressive features capturing the hearts of many fans. His 유중라인 is truly remarkable and he receives a lot of love from fans.', additional_kwargs={}, response_metadata={})],
#  'response': '유중라인은 중국 배우인 예숙후의 별명입니다. 그의 매력적인 외모와 유중한 라인이 팬들의 마음을 사로잡았습니다.'}

# %%
print_memory()
# Out:
# {'history': [SystemMessage(content='The human mentions that it might be time to send a laptop. The AI agrees that sending a laptop could be a good decision and asks for more details on the brand or model to provide further information. The conversation then shifts to discussing the popular Chinese actor, Yeskyuho, and his good looks that have captured the hearts of many fans. 약소훈도 요즘 핸섬한 유중라인으로 올라탔어! The AI agrees that Yeskyuho is indeed handsome and charming, with his impressive features capturing the hearts of many fans. His 유중라인 is truly remarkable and he receives a lot of love from fans. 유중라인은 중국 배우인 예숙후의 별명입니다. 그의 매력적인 외모와 유중한 라인이 팬들의 마음을 사로잡았습니다.', additional_kwargs={}, response_metadata={})]}

# %% [markdown]
# ## ConversationKGMemory

# %%
from langchain_community.memory.kg import ConversationKGMemory

# %%
memory = ConversationKGMemory(llm=llm)

# %%
chain = ConversationChain(memory=memory, llm=llm)

# %%
chain.invoke("세종이는 피부가 뽀얗게 변해서 왔어! 올림피아 사우나가 그런 피부에 도움을 줬어!")
chain.invoke("올림피아 사우나는 계란과 식혜를 팔아! 민균이는 식혜을 먹었고, 철민이는 구운 계란를 먹었어!")

chain.invoke("세종이가 간 사우나에서 음식을 먹은 사람은?")
# Out:
# {'input': '세종이가 간 사우나에서 음식을 먹은 사람은?',
#  'history': 'On 세종이: 세종이 피부가 뽀얗게 변해서 왔어 .',
#  'response': '세종이가 간 사우나에서 음식을 먹은 사람은 김태희 씨입니다.'}

# %%
memory.load_memory_variables({"input": "올림피아 사우나는 계란과 식혜를 팔아! 민균이는 식혜을 먹었고, 철민이는 구운 계란를 먹었어!"})
# Out:
# {'history': 'On 올림피아 사우나: 올림피아 사우나 도움을 줬어 피부에.'}

# %%
chain.invoke("내 취미는 축구, 야구, 농구야!")
chain.invoke("내가 좋아하는 음식은 돈까스, 치킨, 스테이크야!")

chain.invoke("내가 좋아하는 음식은?")
# Out:
# {'input': '내가 좋아하는 음식은?',
#  'history': '',
#  'response': '죄송합니다, 그 정보는 제가 알 수 없습니다. 하지만 대부분의 사람들이 피자, 파스타, 스테이크 등을 좋아하는 것으로 알려져 있습니다. 혹시 특별히 좋아하는 음식이 있으신가요?'}

# %% [markdown]
# ## LCEL 방법 *권장*

# %%
# MessagesPlaceholder: 프롬프트 안에 “대화 기록”을 끼워 넣는 자리표시 역할
# InMemoryChatMessageHistory: 대화 내용을 메모리에 저장
# RunnableWithMessageHistory: 체인 + 메모리 + 프롬프트를 자동으로 연결해주는 랩퍼
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", """
        휴먼을 도와주는 AI 도구입니다. 친절하게 답변하세요.
    """),
    # ※ 저장소 메모리 위치
    MessagesPlaceholder(variable_name="chat_history"),
    ("human", "{question}"),
])

# %%
chain = prompt | chat

# %% [markdown]
# ## 저장소(메모리) 생성

# %%
# redis, db
store = {}

def get_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return  store[session_id]

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "내 이름은 세환이야!",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(result.content)
# Out:
# 안녕, 세환이! 만나서 반가워. 무엇을 도와드릴까?

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 세환이야!
# AI: 안녕, 세환이! 만나서 반가워. 무엇을 도와드릴까?

# %%
result = chain_with_memory.invoke(
    {
        "question": "나는 오늘 저녁에 김치찌개를 먹을거야!",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
result = chain_with_memory.invoke(
    {
        "question": "난 오늘 저녁에 무엇을 먹을 것 같아?",
    },
    config={"configurable": {"session_id": "user1"}}
)

# %%
print(store["user1"])
# Out:
# Human: 내 이름은 세환이야!
# AI: 안녕, 세환이! 만나서 반가워. 무엇을 도와드릴까?
# Human: 나는 오늘 저녁에 김치찌개를 먹을거야!
# AI: 김치찌개는 정말 맛있는 선택이야! 집에서 직접 만들어 먹을 거니까 재료를 잘 준비하고 맛있게 요리해보는 건 어떨까? 만들 때 즐거운 시간 보내길 바래!
# Human: 난 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택이 어려우시군요! 어떤 음식을 좋아하시나요? 한식, 중식, 양식 중에서 어떤 종류의 음식을 먹고 싶으신가요? 제가 도와드릴 수 있도록 자세한 정보를 알려주세요.

# %%
chain_with_memory = RunnableWithMessageHistory(
    chain,
    get_history,
    input_messages_key="question",
    history_messages_key="chat_history"
).with_config(
    configurable={"session_id": "user2"}
)

# %%
result = chain_with_memory.invoke({
    "question": "난 오늘 저녁에 무엇을 먹을 것 같아?",
})

# %%
print(store["user2"])
# Out:
# Human: 난 오늘 저녁에 무엇을 먹을 것 같아?
# AI: 음식 선택은 개인 취향에 따라 다를 수 있지만, 몇 가지 제안을 드릴게요. 한식을 좋아하신다면 비빔밥이나 불고기, 중식을 좋아하신다면 짜장면이나 탕수육, 양식을 좋아하신다면 파스타나 스테이크를 먹어보시는 것은 어떨까요? 또는 샐러드나 샌드위치로 가벼운 식사를 즐기시는 것도 좋은 선택일 수 있어요. 오늘의 기분에 맞게 맛있는 음식을 즐기시길 바랍니다!
